# %% [markdown]
# <a href="https://colab.research.google.com/github/SurendraPrasadSH/AnimeRecommendation/blob/main/AnimeRecommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./anime.csv')

# %%
print(df.shape)
# Out:
# (24012, 31)
